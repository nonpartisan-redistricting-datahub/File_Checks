# %%
import pandas as pd
import geopandas as gp
import os

# %%
pl_2020_st_geo_counts = {'md': {'b': 83827,
  'cnty': 24,
  'sldu': 48,
  't': 1475,
  'bg': 4079,
  'st': 1,
  'place': 536,
  'vtd': 2042,
  'sldl': 68,
  'cd': 8},
 'ri': {'b': 25649,
  'st': 1,
  'bg': 792,
  'sldl': 75,
  'cd': 2,
  't': 250,
  'aiannh': 1,
  'cnty': 5,
  'sldu': 38,
  'place': 36,
  'vtd': 423},
 'mo': {'vtd': 4604,
  'sldl': 163,
  'b': 253632,
  't': 1654,
  'sldu': 34,
  'st': 1,
  'place': 1082,
  'bg': 5031,
  'cnty': 115,
  'cd': 8},
 'me': {'b': 47138,
  'sldl': 151,
  'vtd': 209,
  't': 407,
  'aiannh': 8,
  'cd': 2,
  'cnty': 16,
  'bg': 1184,
  'place': 155,
  'st': 1,
  'sldu': 35},
 'nh': {'vtd': 326,
  'st': 1,
  'bg': 997,
  'sldl': 161,
  't': 350,
  'cd': 2,
  'place': 100,
  'sldu': 24,
  'b': 31948,
  'cnty': 10},
 'sc': {'vtd': 2268,
  'sldl': 124,
  'place': 475,
  'b': 146844,
  'cd': 7,
  'sldu': 46,
  'st': 1,
  'aiannh': 9,
  't': 1323,
  'cnty': 46,
  'bg': 3408},
 'ma': {'cd': 9,
  'cnty': 14,
  'place': 248,
  'st': 1,
  't': 1620,
  'sldu': 40,
  'bg': 5116,
  'aiannh': 3,
  'b': 107278,
  'sldl': 161,
  'vtd': 2157},
 'ut': {'sldu': 29,
  'place': 333,
  'aiannh': 9,
  'cnty': 29,
  't': 716,
  'st': 1,
  'sldl': 75,
  'bg': 2020,
  'vtd': 2745,
  'cd': 4,
  'b': 71207},
 'mn': {'aiannh': 22,
  'b': 198705,
  'sldu': 67,
  'cnty': 87,
  't': 1505,
  'cd': 8,
  'vtd': 4110,
  'place': 913,
  'sldl': 134,
  'st': 1,
  'bg': 4706},
 'tn': {'place': 504,
  'sldu': 33,
  'cnty': 95,
  'b': 179717,
  'sldl': 99,
  'bg': 4562,
  'aiannh': 1,
  'st': 1,
  't': 1701,
  'vtd': 1965,
  'cd': 9},
 'il': {'b': 369978,
  'sldu': 60,
  'place': 1466,
  'vtd': 10084,
  'cnty': 102,
  'cd': 19,
  't': 3265,
  'sldl': 119,
  'st': 1,
  'bg': 9898},
 'va': {'b': 163491,
  'cd': 11,
  'sldl': 100,
  'bg': 5963,
  'place': 672,
  'st': 1,
  'aiannh': 5,
  'vtd': 2465,
  't': 2198,
  'sldu': 40,
  'cnty': 133},
 'ne': {'st': 1,
  'vtd': 1402,
  'sldu': 49,
  'bg': 1648,
  't': 553,
  'cd': 3,
  'cnty': 93,
  'b': 119103,
  'place': 590,
  'aiannh': 9},
 'nv': {'t': 779,
  'vtd': 2102,
  'aiannh': 34,
  'bg': 1963,
  'sldu': 21,
  'st': 1,
  'cnty': 17,
  'cd': 4,
  'b': 57409,
  'sldl': 42,
  'place': 133},
 'nd': {'cd': 1,
  'sldl': 47,
  'aiannh': 7,
  'st': 1,
  't': 228,
  'bg': 632,
  'sldu': 47,
  'vtd': 421,
  'b': 84566,
  'cnty': 53,
  'place': 406},
 'ny': {'place': 1293,
  'cnty': 62,
  'sldu': 63,
  'b': 288819,
  'vtd': 14191,
  'aiannh': 11,
  'bg': 16070,
  'st': 1,
  't': 5411,
  'sldl': 150,
  'cd': 27},
 'nj': {'b': 137972,
  'cnty': 21,
  'aiannh': 2,
  'vtd': 6361,
  'place': 701,
  'sldu': 40,
  't': 2181,
  'st': 1,
  'bg': 6599,
  'cd': 12,
  'sldl': 40},
 'mt': {'cd': 1,
  'sldu': 50,
  'vtd': 666,
  'cnty': 56,
  'st': 1,
  'place': 497,
  'bg': 900,
  't': 319,
  'sldl': 100,
  'aiannh': 14,
  'b': 88417},
 'in': {'cd': 9,
  'vtd': 5159,
  't': 1696,
  'st': 1,
  'aiannh': 1,
  'bg': 5290,
  'sldl': 100,
  'cnty': 92,
  'b': 204568,
  'place': 696,
  'sldu': 50},
 'nc': {'aiannh': 8,
  'bg': 7111,
  't': 2672,
  'st': 1,
  'cnty': 100,
  'cd': 13,
  'sldu': 50,
  'b': 236638,
  'vtd': 2666,
  'sldl': 120,
  'place': 776},
 'ga': {'sldu': 56,
  'bg': 7446,
  'st': 1,
  't': 2796,
  'place': 675,
  'cnty': 159,
  'cd': 14,
  'vtd': 2698,
  'sldl': 180,
  'b': 232717,
  'aiannh': 2},
 'tx': {'sldu': 31,
  'cd': 36,
  't': 6896,
  'bg': 18638,
  'cnty': 254,
  'st': 1,
  'sldl': 150,
  'place': 1860,
  'aiannh': 6,
  'vtd': 9007,
  'b': 668757},
 'la': {'cnty': 64,
  't': 1388,
  'vtd': 3540,
  'sldu': 40,
  'b': 142874,
  'aiannh': 16,
  'cd': 6,
  'place': 488,
  'sldl': 106,
  'bg': 4294,
  'st': 1},
 'nm': {'sldl': 70,
  'vtd': 1977,
  'place': 527,
  'b': 107215,
  'aiannh': 38,
  'sldu': 42,
  'cd': 3,
  'bg': 1614,
  'cnty': 33,
  't': 612,
  'st': 1},
 'ks': {'vtd': 4240,
  't': 829,
  'sldl': 125,
  'aiannh': 7,
  'place': 740,
  'cnty': 105,
  'b': 172529,
  'cd': 4,
  'bg': 2461,
  'sldu': 40,
  'st': 1},
 'id': {'bg': 1284,
  'sldl': 35,
  'aiannh': 7,
  't': 456,
  'st': 1,
  'vtd': 931,
  'cd': 2,
  'sldu': 35,
  'b': 81879,
  'place': 237,
  'cnty': 44},
 'ar': {'sldu': 35,
  't': 823,
  'cnty': 75,
  'cd': 4,
  'sldl': 100,
  'vtd': 2747,
  'place': 626,
  'b': 136422,
  'st': 1,
  'bg': 2294},
 'ca': {'b': 519723,
  'vtd': 58,
  'sldl': 80,
  'place': 1611,
  'bg': 25607,
  't': 9129,
  'cnty': 58,
  'st': 1,
  'aiannh': 150,
  'sldu': 40,
  'cd': 53},
 'or': {'bg': 2970,
  'b': 130807,
  'st': 1,
  'aiannh': 18,
  'vtd': 36,
  'sldl': 60,
  'cd': 5,
  't': 1001,
  'place': 426,
  'sldu': 30,
  'cnty': 36},
 'oh': {'sldl': 100,
  'place': 1265,
  't': 3168,
  'bg': 9472,
  'sldu': 34,
  'st': 1,
  'vtd': 8941,
  'cnty': 88,
  'cd': 16,
  'b': 276428},
 'wy': {'vtd': 512,
  'aiannh': 2,
  'b': 53769,
  'cnty': 23,
  'sldu': 30,
  'cd': 1,
  't': 160,
  'place': 205,
  'st': 1,
  'sldl': 60,
  'bg': 457},
 'wi': {'bg': 4692,
  'st': 1,
  'sldu': 33,
  'place': 804,
  't': 1542,
  'cd': 8,
  'cnty': 72,
  'sldl': 99,
  'b': 203059,
  'vtd': 7059,
  'aiannh': 21},
 'pa': {'sldl': 203,
  'b': 336985,
  'vtd': 9178,
  'sldu': 50,
  'place': 1888,
  'bg': 10173,
  'st': 1,
  't': 3446,
  'cnty': 67,
  'cd': 18},
 'hi': {'t': 461,
  'sldu': 25,
  'place': 163,
  'aiannh': 75,
  'cnty': 5,
  'st': 1,
  'b': 14732,
  'sldl': 51,
  'bg': 1083,
  'cd': 2,
  'vtd': 5},
 'wa': {'sldl': 49,
  'b': 158093,
  'aiannh': 50,
  'sldu': 49,
  'cd': 10,
  'place': 639,
  'vtd': 7434,
  't': 1784,
  'st': 1,
  'cnty': 39,
  'bg': 5311},
 'ak': {'t': 177,
  'cnty': 30,
  'sldu': 20,
  'st': 1,
  'b': 28568,
  'aiannh': 222,
  'vtd': 456,
  'bg': 504,
  'cd': 1,
  'sldl': 40,
  'place': 355},
 'ms': {'t': 878,
  'bg': 2445,
  'st': 1,
  'place': 428,
  'vtd': 1834,
  'cd': 4,
  'sldl': 122,
  'b': 112241,
  'cnty': 82,
  'aiannh': 2,
  'sldu': 52},
 'fl': {'t': 5160,
  'sldl': 120,
  'vtd': 7211,
  'st': 1,
  'aiannh': 11,
  'b': 390066,
  'bg': 13388,
  'sldu': 40,
  'place': 955,
  'cd': 27,
  'cnty': 67},
 'az': {'bg': 4773,
  'st': 1,
  'sldl': 30,
  'place': 467,
  'cd': 9,
  'b': 155444,
  'aiannh': 29,
  'sldu': 30,
  'vtd': 1538,
  't': 1765,
  'cnty': 15},
 'de': {'cnty': 3,
  'cd': 1,
  't': 262,
  'sldu': 21,
  'bg': 706,
  'st': 1,
  'vtd': 412,
  'aiannh': 2,
  'place': 79,
  'b': 20198,
  'sldl': 41},
 'wv': {'cd': 3,
  'sldu': 17,
  'place': 439,
  'vtd': 1064,
  'st': 1,
  't': 546,
  'bg': 1639,
  'cnty': 55,
  'sldl': 67,
  'b': 72558},
 'ct': {'b': 49926,
  'place': 215,
  'sldl': 152,
  'bg': 2716,
  'sldu': 37,
  'aiannh': 6,
  't': 883,
  'st': 1,
  'vtd': 766,
  'cd': 6,
  'cnty': 8},
 'ky': {'t': 1306,
  'sldl': 100,
  'vtd': 3693,
  'st': 1,
  'sldu': 38,
  'b': 132662,
  'bg': 3581,
  'cd': 6,
  'place': 555,
  'cnty': 120},
 'ia': {'place': 1028,
  'sldl': 100,
  'b': 175199,
  'vtd': 2536,
  'cd': 4,
  'sldu': 50,
  'aiannh': 5,
  'st': 1,
  'bg': 2703,
  'cnty': 99,
  't': 896},
 'co': {'cd': 7,
  'sldu': 35,
  't': 1447,
  'bg': 4058,
  'st': 1,
  'cnty': 64,
  'sldl': 65,
  'b': 140345,
  'aiannh': 2,
  'vtd': 3108,
  'place': 482},
 'al': {'sldl': 105,
  't': 1437,
  'aiannh': 9,
  'cd': 7,
  'sldu': 35,
  'vtd': 1837,
  'bg': 3925,
  'st': 1,
  'cnty': 67,
  'b': 185976,
  'place': 593},
 'vt': {'place': 180,
  'b': 24611,
  'cd': 1,
  'bg': 552,
  'sldl': 104,
  'st': 1,
  'cnty': 14,
  't': 193,
  'vtd': 285,
  'sldu': 13},
 'sd': {'cnty': 66,
  'b': 71383,
  'place': 486,
  'sldu': 35,
  'vtd': 785,
  'bg': 694,
  'st': 1,
  't': 242,
  'cd': 1,
  'sldl': 37,
  'aiannh': 16},
 'ok': {'cd': 5,
  'b': 180154,
  'bg': 3374,
  'vtd': 1947,
  'sldl': 101,
  'st': 1,
  'place': 843,
  'aiannh': 30,
  'cnty': 77,
  't': 1205,
  'sldu': 48},
 'mi': {'aiannh': 24,
  'sldl': 111,
  'b': 254730,
  'bg': 8386,
  'cnty': 83,
  'place': 745,
  'st': 1,
  'sldu': 39,
  'vtd': 4805,
  't': 3017,
  'cd': 15}}

# %%
def is_census_geo(path, st, geo_level):
    if ".csv" in path:
        file_type = ".csv"
        load = pd.read_csv(path)
    elif ".shp" in path:
        file_type = ".shp"
        load = gp.read_file(path)
    else:
        raise ValueError ("Need different function to load file at that path")
    file_len = load.shape[0]
    census_len = pl_2020_st_geo_counts[st][geo_level]
    
    if file_len != census_len:
        print("Length does not match PL data")
    else:
        print("Length matches PL data")

# %%
path = "is_census_geo(path, st, geo_level)"

is_census_geo("/Users/peterhorton/Downloads/id_pl2020_b/id_pl2020_b.csv", "id", "b")
# Out:
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_37353/2579375715.py:4: DtypeWarning: Columns (29,31,37,38,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   load = pd.read_csv(path)
# Length matches PL data
